# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
# File to Load (Remember to Change These)
#csv_file = "Project1/Labour_Force.csv"
# labour_force = pd.read_csv('labour_force_data.csv')
# # population_aus = pd.read_csv('populationaus.csv')

# labour_force
labour_force = "Resources/labour_force_data.csv"
labour_force_1 = "Resources/Age_Demographics_1.csv"
labour_force_2 = "Resources/Age_Demographics_2.csv"
population_aus = "Resources/populationaus.csv"

labour_force_df = pd.read_csv(labour_force)
labour_force1_df = pd.read_csv(labour_force_1)
labour_force2_df = pd.read_csv(labour_force_2)
population_aus_df = pd.read_csv(population_aus)

# %%
# Merge the first two datasets on "Wrestler" so that no data is lost (should be 182 rows)
combined_age_df = pd.merge(labour_force_df, labour_force1_df, how='outer', on='Year')
combined_age_df
# Out:
#    Year  Employed total   Persons   Employed full-time  Persons   \
# 0  2012                    11133.0                        7953.6
# 1  2013                    11136.7                        7852.5
# 2  2014                    11306.8                        7974.6
# 3  2015                    11571.2                        8148.8
# 4  2016                    11684.7                        8133.6
# 5  2017                    12047.8                        8419.7
# 6  2018                    12282.2                        8565.8
#
#    Employed part-time  Persons   Employment to population ratio  Persons   \
# 0                        3179.4                                      73.0
# 1                        3284.2                                      72.1
# 2                        3332.2                                      72.4
# 3                        3422.3                                      73.3
# 4                        3551.2                                      73.1
# ...

# %%
combined_age_df = pd.merge(combined_age_df, labour_force2_df, how="outer", on="Year")
combined_age_df
# Out:
#    Year  Employed total   Persons   Employed full-time  Persons   \
# 0  2012                    11133.0                        7953.6
# 1  2013                    11136.7                        7852.5
# 2  2014                    11306.8                        7974.6
# 3  2015                    11571.2                        8148.8
# 4  2016                    11684.7                        8133.6
# 5  2017                    12047.8                        8419.7
# 6  2018                    12282.2                        8565.8
#
#    Employed part-time  Persons   Employment to population ratio  Persons   \
# 0                        3179.4                                      73.0
# 1                        3284.2                                      72.1
# 2                        3332.2                                      72.4
# 3                        3422.3                                      73.3
# 4                        3551.2                                      73.1
# ...

# %%
combined_age_df = combined_age_df.fillna(0)
combined_age_df
# Out:
#    Year  Employed total   Persons   Employed full-time  Persons   \
# 0  2012                    11133.0                        7953.6
# 1  2013                    11136.7                        7852.5
# 2  2014                    11306.8                        7974.6
# 3  2015                    11571.2                        8148.8
# 4  2016                    11684.7                        8133.6
# 5  2017                    12047.8                        8419.7
# 6  2018                    12282.2                        8565.8
#
#    Employed part-time  Persons   Employment to population ratio  Persons   \
# 0                        3179.4                                      73.0
# 1                        3284.2                                      72.1
# 2                        3332.2                                      72.4
# 3                        3422.3                                      73.3
# 4                        3551.2                                      73.1
# ...

# %%
combined_age_df['Year'] = combined_age_df['Year'].astype(int)
combined_age_df
# Out:
#    Year  Employed total   Persons   Employed full-time  Persons   \
# 0  2012                    11133.0                        7953.6
# 1  2013                    11136.7                        7852.5
# 2  2014                    11306.8                        7974.6
# 3  2015                    11571.2                        8148.8
# 4  2016                    11684.7                        8133.6
# 5  2017                    12047.8                        8419.7
# 6  2018                    12282.2                        8565.8
#
#    Employed part-time  Persons   Employment to population ratio  Persons   \
# 0                        3179.4                                      73.0
# 1                        3284.2                                      72.1
# 2                        3332.2                                      72.4
# 3                        3422.3                                      73.3
# 4                        3551.2                                      73.1
# ...

# %%
population_aus_df.head()
# Out:
#    Year       AUS      NSW      VIC      QLD       SA       WA     TAS  \
# 0  2012  22522197  7258722  5591818  4518649  1647183  2385947  511739
# 1  2013  23297777  7454938  5832585  4685439  1678052  2502188  513015
# 2  2014  23640331  7562171  5957512  4747263  1693107  2528619  514040
# 3  2015  23984581  7671401  6093049  4804933  1705937  2547745  515694
# 4  2016  24389684  7801785  6244863  4883821  1717400  2563708  519810
#
#        NT     ACT
# 0  232952  372070
# 1  242304  386318
# 2  242753  391981
# 3  244090  398874
# 4  246183  407489

# %%
# population_aus_df = population_aus_df.drop(column=['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT'])
population_aus_df.drop(['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT'], axis='columns', inplace=True)
population_aus_df
# Out:
#    Year       AUS
# 0  2012  22522197
# 1  2013  23297777
# 2  2014  23640331
# 3  2015  23984581
# 4  2016  24389684
# 5  2017  24773350
# 6  2018  25171291

# %%
# population_aus_df = population_aus_df.drop(['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT'])
combined_age_df = pd.merge(combined_age_df, population_aus_df, how="outer", on="Year")
combined_age_df = combined_age_df.T.drop_duplicates().T
combined_age_df['Year'] = combined_age_df['Year'].astype(int)
combined_age_df
# Out:
#    Year  Employed total   Persons   Employed full-time  Persons   \
# 0  2012                    11133.0                        7953.6
# 1  2013                    11136.7                        7852.5
# 2  2014                    11306.8                        7974.6
# 3  2015                    11571.2                        8148.8
# 4  2016                    11684.7                        8133.6
# 5  2017                    12047.8                        8419.7
# 6  2018                    12282.2                        8565.8
#
#    Employed part-time  Persons   Employment to population ratio  Persons   \
# 0                        3179.4                                      73.0
# 1                        3284.2                                      72.1
# 2                        3332.2                                      72.4
# 3                        3422.3                                      73.3
# 4                        3551.2                                      73.1
# ...

# %%
combined_age_df.describe()
# Out:
#               Year  Employed total   Persons   Employed full-time  Persons   \
# count     7.000000                   7.000000                      7.000000
# mean   2015.000000               11594.628571                   8149.800000
# std       2.160247                 445.799913                    259.403874
# min    2012.000000               11133.000000                   7852.500000
# 25%    2013.500000               11221.750000                   7964.100000
# 50%    2015.000000               11571.200000                   8133.600000
# 75%    2016.500000               11866.250000                   8284.250000
# max    2018.000000               12282.200000                   8565.800000
#
#        Employed part-time  Persons   Employment to population ratio  Persons   \
# count                      7.000000                                  7.000000
# mean                    3444.828571                                 73.300000
# ...

# %%
mean = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].mean()
median =combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].median()
variance = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].var()
stdv = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].std()
sem = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].sem()


# This method is the most straighforward, creating multiple series and putting them all together at the end.
summary_age_df = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": stdv, 
                          "SEM": sem})
summary_age_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-1acb29172920> in <module>
# ----> 1 mean = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].mean()
#       2 median =combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].median()
#       3 variance = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].var()
#       4 stdv = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].std()
#       5 sem = combined_age_df.groupby('Year')['Civilian population aged 15-64 years Persons'].sem()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1601                 stacklevel=2,
#    1602             )
# -> 1603         return super().__getitem__(key)
#    1604
# ...

# %%
mean= combined_age_df('Civilian population aged 15-64 years ').mean()
print("Mean of total working population aged 15-64 years is 15814")
print("")
print("1st Quartile of total working population aged 15-64 is 15525")
print("")

print("3rd Quartile of total working population aged 15-64 is 16095")
print("")
print("Maximum of total working population aged 15-64 years is 16417")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-2e395dd25157> in <module>
# ----> 1 mean= combined_age_df('Civilian population aged 15-64 years ').mean()
#       2 print("Mean of total working population aged 15-64 years is 15814")
#       3 print("")
#       4 print("1st Quartile of total working population aged 15-64 is 15525")
#       5 print("")
#
# TypeError: 'DataFrame' object is not callable

# %%
# labour_force.plot(x="Employed total persons", y="Year", kind="bar", rot=5, fontsize=4)
combined_age_df.iloc[ :6].plot(kind="bar", figsize=(15,10))
# combined_age_df.iloc[1, 9:4].plot(kind="bar", figsize=(15,10))
plt.title("Total working population aged 15-64 years/Gender")
plt.xlabel('Age group')
plt.ylabel('Total Population')
# combined_age_df.plot(x="Year", y= "Employed Total Persons" ,kind="bar", rot=5, fontsize=4)
# working age population vs total populaton
# Out:
# Text(0, 0.5, 'Total Population')

# %%
import numpy as np
import matplotlib.pyplot as plt


# N = 7
total = (15257.4 ,15439.4, 15612.4, 15781, 15990.4, 16199.7, 16417.7)

males = (7616.9, 7692.8,7770.2,7841.1,7937.3, 8038.7, 8149.2)
females = (7640.5, 7746.6, 7842.2, 7940, 8053.1, 8161, 8268.5)
# womenStd = (3, 5, 2, 3, 3)
ind = np.arange(len(bars))    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
total_deviation = np.std(total)
males_deviation = np.std(males)
females_deviation = np.std(females)
bars = ['2012', '2013', '2014', '2015', '2016', '2017', '2018']
ind = np.arange(len(bars))
bar_categories = ['2012', '2013', '2014', '2015', '2016', '2017', '2018'];
bar_width = 0.5
bar_padding = np.add(males, females).tolist()


plt.bar(ind, total, yerr=total_deviation, width=bar_width)
plt.bar(ind, males, yerr=males_deviation, bottom=males, width=bar_width)
plt.bar(ind, females, yerr=females_deviation, bottom=bar_padding, width=bar_width)

plt.xticks(ind, bar_categories)
plt.xlabel("Stacked Bar Plot")

plt.show()

# p1 = plt.bar(ind, total)
# p2 = plt.bar(ind, males)
# p3 = plt.bar(ind, females)

# plt.ylabel('Years')
# plt.title('Working population  by group and gender')
# plt.xticks(ind, ('2012', '2013', '2014', '2015', '2016', '2017', '2018'))
# plt.yticks(np.arange(7000,18000 , 20))
# plt.legend((p1[0], p2[0]), p3[0], ('total', 'Males', 'Females'))

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-53fb7e43cf87> in <module>
#       9 females = (7640.5, 7746.6, 7842.2, 7940, 8053.1, 8161, 8268.5)
#      10 # womenStd = (3, 5, 2, 3, 3)
# ---> 11 ind = np.arange(len(bars))    # the x locations for the groups
#      12 width = 0.35       # the width of the bars: can also be len(x) sequence
#      13 total_deviation = np.std(total)
#
# NameError: name 'bars' is not defined

# %%
population_aus_df.iloc[1:].plot(label = "population")
combined_age_df.iloc[-10:].plot(label = "Employed total Persons")

# population = population_aus.iloc[0, 0:6]
# employ = df.iloc[10, 0:6]

# capomulin_single_df = capomulin_single_df.loc[:, ["Timepoint", "Tumor Volume (mm3)"]]

# labour_force = labour_force.reset('Year')
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
# combined_age_df.plot(figsize=(10, 8), linewidth=2.5, color='green')
# plt.title('Capomulin treatmeant of mouse')

# plt.xlabel('Timepoint (Days)')
# plt.ylabel('Tumor Volume (mm3)')

# %%
# total_df = pd.DataFrame(mouse_study_df.groupby(["Drug Regimen"]).count()).reset_index()
# data = df[["Employed total Persons","Year"]]
# regimen_data = regimen_data.rename(columns={"Mouse ID": "Count"})

# regimen_data = regimen_data.set_index("Year")
employ = combined_age_df.iloc[-3, 0:6].plot(label = "Employed total Persons")
year = combined_age_df.iloc[:-10].plot(label = "Year")
# employ.plot(kind="bar", figsize=(12,4))
# year.plot(kind="bar", figsize=(12,4))
# year.ploy
# Set a title for the chart
plt.title("Employed Total Persons")

plt.show()
plt.tight_layout()

# %%
# employ.plot(kind="bar", figsize=(12,4))
df.plot(kind="bar", figsize=(12,4))
plt.title("Count per Drug Regimen")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-b95304fb24fc> in <module>
#       1 # employ.plot(kind="bar", figsize=(12,4))
# ----> 2 df.plot(kind="bar", figsize=(12,4))
#       3 plt.title("Count per Drug Regimen")
#       4
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
total_df = pd.DataFrame(labour_force_df.groupby(["Year"]).count()).reset_index()
employ_data = total_df["Year","Employed total Persons"]
# employ_data = employ_data.rename(columns={"Mouse ID": "Count"})

employ_data = employ_data.set_index("Year")
employ_data.plot(kind="bar", figsize=(12,4))

# Set a title for the chart
plt.title("Employment rate per year")

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Year', 'Employed total Persons')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-c6117bf4caad> in <module>
# ...

# %%
labour_force_df = labour_force_df.set_index('Year')
labour_force_df.plot(kind="scatter", x="Year", y="Civilian population aged 15-64 years Persons", grid=True, figsize=(10,5),
              title="Civilian population aged 15-64 years per Years")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-ca64aeb7e5a0> in <module>
# ...

# %%
box = labour_force.boxplot(x = "Employed Total person"  , data=population_aus )
box.set_xlabel("Year" )
box.set_ylabel("Year" )
box.set_title("Age Frequency Box Plot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-4179eb45f767> in <module>
# ----> 1 box = labour_force.boxplot(x = "Employed Total person"  , data=population_aus )
#       2 box.set_xlabel("Year" )
#       3 box.set_ylabel("Year" )
#       4 box.set_title("Age Frequency Box Plot")
#
# AttributeError: 'str' object has no attribute 'boxplot'

# %%
print("Minimum Age : ",labour_fore.Age.min())
print("")
print("1st Quartile Age : ",mcr.Age.quantile([0.25]))
print("")
print("Median Age  : ",mcr.Age.quantile([0.5]))
print("")
print("3rd Quartile Age : ",mcr.Age.quantile([0.75]))
print("")
print("Maximum Age : ",mcr.Age.max())
print("")
print("Mean Age : ",round(mcr.Age.mean()))
print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-46daa04dc119> in <module>
# ----> 1 print("Minimum Age : ",labour_fore.Age.min())
#       2 print("")
#       3 print("1st Quartile Age : ",mcr.Age.quantile([0.25]))
#       4 print("")
#       5 print("Median Age  : ",mcr.Age.quantile([0.5]))
#
# NameError: name 'labour_fore' is not defined

# %%
bar = combined_age_df.plot(x = "Year" , y =" "   )
bar.set_xlabel("Frequency" )
bar.set_title("EmploymentStatus Frequency Bar Plot")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' '
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-ce54b949790d> in <module>
# ...

# %%
bar = sns.barplot(x = frequency , y ="Employment Status in accordance with age group and gender"   ,data=mcr  )
bar.set_xlabel("Frequency" )
bar.set_title("EmploymentStatus Frequency Bar Plot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-d5c5df8d94e6> in <module>
# ----> 1 bar = sns.barplot(x = frequency , y ="Employment Status in accordance with age group and gender"   ,data=mcr  )
#       2 bar.set_xlabel("Frequency" )
#       3 bar.set_title("EmploymentStatus Frequency Bar Plot")
#
# NameError: name 'sns' is not defined

# %%
combined_age_df = combined_age_df.loc[:, ["Year", "Civilian population aged 15-64 years Persons"]]

combined_age_df= combined_age_df.reset_index(drop=True)
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
combined_age_df.set_index('Year').plot(figsize=(10, 8), linewidth=2.5, color='green')
plt.title('Capomulin treatmeant of mouse')

plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-200af5ef5c85> in <module>
# ----> 1 combined_age_df = combined_age_df.loc[:, ["Year", "Civilian population aged 15-64 years Persons"]]
#       2
#       3 combined_age_df= combined_age_df.reset_index(drop=True)
#       4 # Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
#       5 combined_age_df.set_index('Year').plot(figsize=(10, 8), linewidth=2.5, color='green')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ...

# %%
combined_age_df.plot(kind="scatter", x="Year", y="Civilian population aged 15-64 years Persons", grid=True, figsize=(10,5),
              title="Weight Vs. Average Tumor Volume")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Civilian population aged 15-64 years Persons'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-d1d8fa8dde32> in <module>
# ...

# %%
# DATA SET 4
x_axis = np.arange(0, 10, 0.1)
times = []
for x in x_axis:
    times.append(x * x + np.random.randint(0, np.ceil(max(x_axis))))

# %%
decrease_df = combined_age_df.loc[:, ["Year", "Civilian population aged 15-64 years Persons", "AUS_x"]]
decrease_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-7b4c88d6d1bb> in <module>
# ----> 1 decrease_df = combined_age_df.loc[:, ["Year", "Civilian population aged 15-64 years Persons", "AUS_x"]]
#       2 decrease_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ...

# %%
x_values = combined_age_df.columns[:,'Year']
y_values = combined_age_df.columns[:,'Civilian population aged 15-64 years Persons']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-f404b945cc03> in <module>
# ----> 1 x_values = combined_age_df.columns[:,'Year']
#       2 y_values = combined_age_df.columns[:,'Civilian population aged 15-64 years Persons']
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3939
#    3940         key = com.values_from_object(key)
# -> 3941         result = getitem(key)
#    3942         if not is_scalar(result):
#    3943             if np.ndim(result) > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plt.scatter(x_values,y_values)

plt.xlabel('Mouse Weight')
plt.ylabel('Average Tumor Volume')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-cbba761360b7> in <module>
# ----> 1 plt.scatter(x_values,y_values)
#       2
#       3 plt.xlabel('Mouse Weight')
#       4 plt.ylabel('Average Tumor Volume')
#       5 plt.show()
#
# NameError: name 'x_values' is not defined

# %%
employ_status= combined_age_df.drop(['Year', 'AUS_x'], axis = 1) 
employ_status
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-20aaf73ac82f> in <module>
# ----> 1 employ_status= combined_age_df.drop(['Year', 'AUS_x'], axis = 1)
#       2 employ_status
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
# plotdata['combined_age_df'].plot(kind="barh")
# combined_age_df.drop(['Year', 'AUS_x'], axis = 1) 
employ_status.plot(kind="barh")
plt.title("Employment Status of Australia working population aged 15-64")
plt.ylabel("Civilian population aged 15-64 years Persons")
plt.xlabel("Year")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-c88b6703e35e> in <module>
#       1 # plotdata['combined_age_df'].plot(kind="barh")
#       2 # combined_age_df.drop(['Year', 'AUS_x'], axis = 1)
# ----> 3 employ_status.plot(kind="barh")
#       4 plt.title("Employment Status of Australia working population aged 15-64")
#       5 plt.ylabel("Civilian population aged 15-64 years Persons")
#
# NameError: name 'employ_status' is not defined

# %%
plt.figure(figsize=(9,6)) 
plt.bar(x=combined_age_df['Year'], 
        height=combined_age_df['Civilian population aged 15-64 years Persons'], 
        color='midnightblue') 
plt.xticks(rotation=45)
plt.title('Car Sales by Brand')
# plt.savefig('Car Sales Bar.png.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Civilian population aged 15-64 years Persons'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-db14874e30ca> in <module>
# ...
